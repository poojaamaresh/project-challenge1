# %% [markdown]
# # DBSCAN Clustering
# The [DBSCAN](http://scikit-learn.org/stable/modules/clustering.html#dbscan) algorithm views clusters as areas of high density separated by areas of low density.
#
# Due to this rather generic view, clusters found by DBSCAN can be any shape, as opposed to k-means which assumes that clusters are convex shaped.
#
# The central component to the DBSCAN is the **concept of core samples, which are samples that are in areas of high density**. A cluster is therefore a set of core samples, each close to each other (measured by some distance measure) and a set of non-core samples that are close to a core sample (but are not themselves core samples).
# ![dbscan](https://3.bp.blogspot.com/-rDYuyg00Z0w/WXA-OQpkAfI/AAAAAAAAI_I/QshfNVNHD_wXJwXEipRIVzDSX5iOEAy2wCEwYBhgL/s1600/DBSCAN_Points.PNG)

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Make moon-shaped and doughnut-shaped data¶

# %%
from sklearn import cluster, datasets

# %%
#preparing datasets that form circles and moons using number of smaple = n_samples
#noise : standard deviation of Guassian noise added to the sample
#factor = radius of inner circle/radius of outer circle
#Similarly generating data points to draw moons
#noise=0.05
#factor = 0.5
n_samples = 1500
noisy_circles,circle_labels = datasets.make_circles(n_samples=n_samples,factor=.5,noise=.05)
noisy_moons,moon_labels = datasets.make_moons(n_samples=n_samples,noise=.1)

# %%
noisy_moons=np.array(noisy_moons)
noisy_circles = np.array(noisy_circles)

# %%
plt.figure(figsize=(8,5))
plt.title("Half-moon shaped data", fontsize=18)
plt.grid(True)
plt.scatter(noisy_moons[:,0],noisy_moons[:,1])
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("Concentric circles of data points", fontsize=18)
plt.grid(True)
plt.scatter(noisy_circles[:,0],noisy_circles[:,1])
plt.show()

# %% [markdown]
# ## Can k-means identify the right clusters?

# %%
#invoking Kmean algorithm, cluster.KMeans returns an object
km=cluster.KMeans(n_clusters=2)

# %%
#preparing the model using Kmeans algorithm
#km.labels_ vriable contains the lables of the clusters
km.fit(noisy_moons)
# Out:
# KMeans(n_clusters=2)

# %% [markdown]
# #different variables stored in the km object, explore them

# %%
#km.cluster_centers_
#km.inertia_
#km.labels_

# %%
#plotting the labels given by kmean algorithm
plt.figure(figsize=(8,5))
plt.title("Half-moon shaped data", fontsize=18)
plt.grid(True)
plt.scatter(noisy_moons[:,0],noisy_moons[:,1],c=km.labels_)
plt.show()

# %%
#Now using noisy_circles data to observe the clusters  
km.fit(noisy_circles)
# Out:
# KMeans(n_clusters=2)

# %%
plt.figure(figsize=(8,5))
plt.title("Concentric circles of data points", fontsize=18)
plt.grid(True)
plt.scatter(noisy_circles[:,0],noisy_circles[:,1],c=km.labels_)
plt.show()

# %% [markdown]
# ## How does DBSCAN perform?

# %%
#Invoking DBSCAN algorithm with eps and min_sample parameter
#change the values and observe
#for eps = 5, all points will be placed in a single cluster
# select different eps values and
dbs = cluster.DBSCAN(eps=0.1,min_samples=20)

# %%
dbs.fit(noisy_moons)
# Out:
# DBSCAN(eps=0.1, min_samples=20)

# %%
#dbs has many varaobles e.g., components, min_samples,

# %%
plt.figure(figsize=(8,5))
plt.title("Half-moon shaped data", fontsize=18)
plt.grid(True)
plt.scatter(noisy_moons[:,0],noisy_moons[:,1],c=dbs.labels_)
plt.show()

# %%
#observe for eps = 3, all data is labelled as a single cluster
#min_smaples =10 
#plot the clusters
dbs = 
d

# %%
#observe for min_samples = 10, observe the number of outliers increased
#observe the outliers that very near to the clusters
dbs = 
#noisy_moons

plt.figure(figsize=(8,5))
plt.title("Half-moon shaped data", fontsize=18)
plt.grid(True)
plt.scatter(noisy_moons[:,0],noisy_moons[:,1],c=dbs.labels_)
plt.show()

# %%
#Now using circles data
dbs.fit(noisy_circles)
# Out:
# DBSCAN(eps=0.1, min_samples=10)

# %%
plt.figure(figsize=(8,5))
plt.title("Concentric circles of data points", fontsize=18)
plt.grid(True)
plt.scatter(noisy_circles[:,0],noisy_circles[:,1],c=dbs.labels_)
plt.show()

# %% [markdown]
# Please go through the documantation of the clustering algorithms
#
# https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html

# %% [markdown]
# * what is the influence of min_smaples and eps??
