# %% [markdown]
# ## In this lab we will learn about
#     1. regularizer
#     2. PCA

# %% [markdown]
# ### Before we proceed let us understand
#     1. what is a regularizer
#     2. How many types of regularizees
#     3. What is the difference between the different regularizers?

# %% [raw]
# 1. For linear regression problem, we consider a data set related to number of appliances that are used from the energy generated by wind mill.
# We see different parameters like pressure and speed of the wind.
#
# Can we understand any other parameters?
#
# 2. For logistic regression problem, we consider a dataset with different attributes of a petioent and predict a person is diabetic or not

# %%
# Import pandas and read the data energydata.csv
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('energydata.csv')
#print the shape
df.shape
# Out:
# (19735, 29)

# %%
#print is there any na s in the data
df.isna().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
#see sample rows
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df1=df.drop(columns=['date','lights'])

# %%
# import libraries required to train_test_split

# Appliances is the target variable
# lights and date are not necessary drop that variable

X=df1.loc[:, df1.columns !='Appliances']
y=df1['Appliances']

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0,train_size=.8)
print(X_train.shape)
print(X_test.shape)
# Out:
# (15788, 26)
# (3947, 26)

# %%
# import standardscalar 
sc = StandardScaler()
X_train_fit=sc.fit(X_train)
# fit train data
X_scalar_train=sc.transform(X_train)
X_scalar_test=sc.transform(X_test)

# why do we fit X_train but transform X_test??

# %%
a=2
b=3
a+b
# Out:
# 5

# %%
#  import Lasso
l1 = 
#fit the model

#predict for both train data and test data
trainpreds = 
testpreds  = 

from sklearn.metrics import mean_absolute_error
print("train error:",mean_absolute_error(y_train,trainpreds))
print("test error:",mean_absolute_error(y_test,testpreds))
# Out:
# train error: 53.95668756178307
# test error: 53.60521170938808

# %%
# import Ridge from sklearn.linear_model import Ridge and repeat the above 
r1 =  
r1.fit
trainpreds = 
testpreds  = 


print("train error:",mean_absolute_error(y_train,trainpreds))
print("test error:",mean_absolute_error(y_test,testpreds))
# Out:
# train error: 53.58730488869554
# test error: 53.01285978872268

# %%
r1.coef_
# Out:
# array([  0.63021659,  62.80699268, -42.83059678, -58.21237726,
#         51.40103827,  16.0422733 ,   6.94875103,   7.09938018,
#         -3.3534058 ,   2.06540519,  45.9335242 ,  11.26524876,
#          0.13633124,  -7.08566104,  19.50723092, -30.71720857,
#        -39.90197215,  -5.22684008, -54.37582188,   1.85279037,
#        -12.50082256,   5.42260506,   2.1413019 ,  19.25742263,
#         -0.34711016,  -0.34711016])

# %%
#import PCA
import numpy as np
from sklearn.decomposition import PCA
pc = PCA()

# %%
# pc.fit 
#what are the input arguements and why
# Out:
# PCA()

# %%
print("Eigen values:",pc.explained_variance_)
print("Eigen vectors:",pc.components_)
# Out:
# Eigen values: [9.30134399e+00 7.06139310e+00 2.00605989e+00 1.82526023e+00
#  1.05789641e+00 9.76888138e-01 9.44438449e-01 5.56075663e-01
#  5.29905338e-01 3.90846219e-01 2.65023642e-01 1.76306262e-01
#  1.44709486e-01 1.38851278e-01 1.18707097e-01 1.14090247e-01
#  9.36934957e-02 7.37810987e-02 6.73557063e-02 4.53550918e-02
#  4.40774750e-02 2.90639534e-02 2.26009711e-02 1.44204520e-02
#  3.73859099e-03 1.69438085e-31]
# Eigen vectors: [[ 3.01228428e-01  8.34861384e-02  2.79471374e-01  1.62631631e-02
#    3.04259113e-01 -7.17508712e-03  2.97966735e-01  4.41436647e-02
#    2.99575853e-01 -2.04342336e-02  2.75851787e-01 -2.43320542e-01
#    2.94929169e-01  5.91500567e-02  2.68096343e-01  4.17015128e-03
#    3.04436700e-01  3.67754951e-02  2.79862776e-01 -5.94954923e-02
#   -1.45171616e-01 -1.49985590e-02 -3.44085335e-02  2.33117507e-01
#    1.22509540e-03  1.22509540e-03]
#  [ 1.18842979e-02 -3.30750277e-01 -2.13999652e-02 -3.03864060e-01
# ...

# %%
# Cumulative variance
np.cumsum(pc.explained_variance_ratio_)
# Out:
# array([0.35876834, 0.62995996, 0.70731533, 0.77710174, 0.81747414,
#        0.85543771, 0.89100281, 0.91249924, 0.93293731, 0.94799574,
#        0.95826806, 0.96499834, 0.97061068, 0.97596883, 0.98049166,
#        0.98490006, 0.9884817 , 0.9912929 , 0.9939065 , 0.99564277,
#        0.99732608, 0.99842007, 0.99930198, 0.99985751, 1.        ,
#        1.        ])

# %%
#plot of the above
from matplotlib import pyplot as plt
plot

# %%
# We will construct the data considering the minimum principle components 
# that constitute 90% of the variance
pc1 = 
train_pca= 
test_pca =

# %%
print(train_pca.shape)
print(test_pca.shape)
# Out:
# (13814, 8)
# (5921, 8)

# %%
#Use lasso regression on the new features (generated using PCA)  
l1_pca = 

#fit the data
# Out:
# Lasso()

# %%
# compute the abosolute error
#what do you observe??
trainpreds = 
testpreds =  

print(mean_absolute_error(y_train,trainpreds))
print(mean_absolute_error(y_test,testpreds))
# Out:
# 58.60397100085669
# 58.74140501557962

# %%
# print the coefficients
# Out:
# array([ 2.52201069,  0.57517462,  2.78199233, 10.13689226,  2.49185255,
#        -1.34794688,  2.16823099, -0.24237127])

# %%
# we will execute LinearRegression algo without a regularizer and compare the performance
from sklearn.linear_model import LinearRegression
linreg = 
#fit
linreg.fit(train_pca,y_train)
trainpreds = 
testpreds =  

print(mean_absolute_error(y_train,trainpreds))
print(mean_absolute_error(y_test,testpreds))
# Out:
# 58.49482678514864
# 58.62118244902035

# %%
linreg.coef_
# Out:
# array([ 2.62921508,  0.71699883,  3.27919817, 10.68802445,  3.44452166,
#        -2.36106391,  3.24967158, -2.03157673])

# %%
# Classification, problem

# %%
labels = ["Pregnant", "Glucose", "BloodPressure", 
                  "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction", 
                  "Age", "Outcome"]
df =

# %%
df.shape
# Out:
# (768, 9)

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X=df.drop(['Outcome'],axis=1)
y=df['Outcome']

X_train,X_test,y_train,y_test = 
print(X_train.shape)
print(X_test.shape)
# Out:
# (537, 8)
# (231, 8)

# %%
from sklearn.preprocessing import StandardScaler
standardizer = 
X_train = 
X_test =

# %%
#Simple logistic regression
from sklearn.linear_model import LogisticRegression
logreg= LogisticRegression()
logreg.fit(X_train,y_train)

from sklearn.metrics import recall_score,accuracy_score,f1_score,precision_score

trainpreds = logreg.predict(X_train)
testpreds = logreg.predict(X_test)

print("accuracy train data",accuracy_score(y_train,trainpreds))
print("accuracy test data",accuracy_score(y_test,testpreds))
# Out:
# accuracy train data 0.7839851024208566
# accuracy test data 0.7662337662337663

# %%
# with l1 regularizer
from sklearn.linear_model import LogisticRegression
logreg1= LogisticRegression(penalty="l1",solver='liblinear')
logreg1.fit(X_train,y_train)

from sklearn.metrics import recall_score,accuracy_score,f1_score,precision_score

trainpreds = logreg1.predict(X_train)
testpreds = logreg1.predict(X_test)

print("accuracy train data",accuracy_score(y_train,trainpreds))
print("accuracy test data",accuracy_score(y_test,testpreds))
# Out:
# accuracy train data 0.7839851024208566
# accuracy test data 0.7705627705627706
